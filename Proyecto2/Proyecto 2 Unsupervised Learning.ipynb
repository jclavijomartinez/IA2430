# %% [markdown]
# # Proyecto II: Aprendizaje no Supervisado
#
# En este proyecto ustedes deberan desarrollar el sistema de recomendación, siguiendo las instrucciones dadas, y uno de los dos problemas siguientes que involucran el uso de estrategias de agrupamiento.
#
# ## Sistema de Recomendación
#
# Se tiene una base de datos de ratings de peliculas, la descripción pueden encontrala [aquí](https://grouplens.org/datasets/movielens/100k/), y los archivos estan adjuntos en la carpeta del taller (data). Esta base de datos cuenta con la calificación de 943 usuarios a 1682 peliculas, en total se dispone de mil calificaciones (entre 0 y 5). Ademas de la lista que relaciona al usuario con la pelicula y el rating dado, además cuentan con información sobre el genero al que pertenece la pelicula (una clasificación de 19 generos diferentes), asi mismo como información relacionada con edad, sexo, y profesion de los diferents usuarios.
#
# Para este ejercicio se desea evaluar el uso de diferentes técnicas de aprendizaje no supervisado. Por lo tanto se deben emplear diferentes técnicas de las vistas en clase. Para este proyecto se cuenta con la siguiente información en diferentes archivos de excel:
#
# 1. **u_data_ratings.xls**: rating de peliculas asignado por un usuario a una pelicula especifica.
# 2. **u_movies_genre.xls**: enumeración de los 20 diferentes generos de peliculas incluidos en la base de datos.
# 3. **u_movies_items.xls**: un archivo que contiene información relacionada con cada una de las peliculas.
# 5. **u_user_info.xls**: información relacionada a los usuarios.
#
# Para el desarrollo de este ejercicio se pide lo siguiente:
#
# 1. Desarrollar un sistema de recomendación de peliculas basado en la información proporcionada.
# 2. Realizar un analisis y descripción de la información presentada utilizando herramientas de aprendizaje no supervisado. ¿Qué puede decir de los datos y su distribución?, ¿qué grupos pueden encontrar?, ¿qué indican esos grupos?, etc...
#
# ¿Qué se debe entregar?
#
# 1. Analisis de la información presentada. ¿Qué se puede inferir de los datos?
# 2. Implementación y explicación del sistema de recomendación. Análisis de los resultados del sistema de recomendación utilizando un ejemplo.
# 3. ¿Cómo puedo evaluar que peliculas le podrian gustar a un usuario nuevo (que no este en la base de datos) basado en las calificaciones que este da a una serie de peliculas?
# 4. Análisis sobre como incorporar toda la información otorgada.
# 5. ¿Qué se puede inferir sobre los diferentes usuarios y sus gustos en peliculas? se puede encontrar alguna relación entre edad, profesión, sexo y genero de peliculas que les gusta a estos grupos? ¿Cómo se podria obtener esta información?
# 6. Durante el desarrollo de cada uno de los puntos del taller indique los métodos utilizados y explique la forma como los utiliza.
# 7. Una discusión sobre el desarrollo del proyecto, los metodos utilizados, posibles mejoras, etc..
#
# # Cuantización de Imágenes
#
# Para este ejercicio se busca cambiar los colores de una imagen por una paleta más limitadas. Suponga que esta paleta limitada contiene máximo 15 colores. Para el ejercicio se utilizaran las obras de arte que se adjuntan en la carpeta de paintings. Deben realizar un proceso de cuantización de color con diferentes tecnicas de agrupamiento. Para este proceso deben seguir tener en cuenta:
#
# 1. ¿Cuantos colores van a utilizar? (Número de clusters)
# 2. ¿Cuál es la mejor pintura cuantizada, es decir cual presenta el menor error al reconstruirla con el conjunto de colores básico?
# 3. Mostrar como se verian las pinturas utilizando solamente la limitada paleta de colores.
#
#
# Ademas deben contestar las siguientes preguntas:
#
# 1. ¿Esta a gusto con la cuantización realizada?
# 2. ¿Cómo puede mejorar los resultados?
# 3. Describa brevemente que han hecho los algoritmos de clustering y sus diferencias. Puede usar figuras, gráficas, etc para complementar esta respuesta.
# 4. ¿Qué problemas tuvo a la hora de realizar esta parte del proyecto?
#
# # Rastreo de objetos
#
# Para esta tarea se busca realizar la segmentación de una imagen de tráfico, donde se identifique los automoviles. El video que deben procesar se encuentra en la carpeta Object Tracking. Para realizar esta implementación deben basarse en el paper adjunto en la misma carpeta, y en la explicación presentada [aqui](https://www.youtube.com/watch?v=0nz8JMyFF14).
#
# Para esta tarea se debe entregar:
#
# 1. Algoritmos realizando la segmentación de los videos.
# 2. Una explicación general del algoritmo implementado.
#
# Además deben contestar las siguientes preguntas:
#
# 1. ¿Esta a gusto con la segmentación realizada?
# 2. ¿Cómo puede mejorar los resultados?
# 3. Describa brevemente cómo funciona el algoritmo, donde comete errores y ¿por qué?
# 4. ¿Qué problemas tuvo a la hora de realizar esta parte del proyecto?
#
#
# Finalmente, el proyecto se debe entregar en un notebook de jupyter con el material de apoyo necesario, el código documentado con el análisis de cada una de las partes, y las respuestas a las preguntas realizadas. Pueden hacerse en grupos de no más de 3 personas.
#
# Recuerde colocar los nombres de los participantes al comienzo del notebook que entregan.
#
# Nota: Recuerden que tienen hasta el **Domingo 13 de Octubre** a las 11:59 de la noche para entregar sus notebooks, utilizando el link de Teams. Mucha suerte!!
